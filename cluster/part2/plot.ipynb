# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df = np.load('./data/SFP_hx_strict.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

plt.plot(temps, np.abs(Fuu_px-Fdd_px)/2, linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.abs(Fuu_py-Fdd_py)/2, "--", linewidth=1, label=r"$p_y$-wave", color='red')

plt.ylim(0,0.05)
plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df1 = np.load('./data/SFP_U3.npz')
temps1 = df1["temps"]
F01 = df1["F0"]
F_swave1 = df1["F_swave"]
F_dwave1 = df1["F_dwave"]
F_px1 = df1["F_px"]
F_py1 = df1["F_py"]
Fuu_px1 = df1["Fuu_px"]
Fuu_py1 = df1["Fuu_py"]
Fdd_px1 = df1["Fdd_px"]
Fdd_py1 = df1["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps1, np.abs(F01), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps1, np.abs(F_px1), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps1, np.abs(F_py1), "--", linewidth=1, label=r"$p_y$-wave", color='red')

# plt.ylim(0,0.05)
# plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df2 = np.load('./data/SFP_U5.npz')
temps2 = df2["temps"]
converged2 = df2["converged"]
F02 = df2["F0"]
F_swave2 = df2["F_swave"]
F_dwave2 = df2["F_dwave"]
F_px2 = df2["F_px"]
F_py2 = df2["F_py"]
Fuu_px2 = df2["Fuu_px"]
Fuu_py2 = df2["Fuu_py"]
Fdd_px2 = df2["Fdd_px"]
Fdd_py2 = df2["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.abs(F0), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps2, np.abs(F_px2), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps2, np.abs(F_py2), "--", linewidth=1, label=r"$p_y$-wave", color='red')

# plt.ylim(0,0.05)
# plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# print(converged2)

# %%
df4 = np.load('./data/SFP_U6.npz')
temps4 = df4["temps"]
converged4 = df4["converged"]
F04 = df4["F0"]
F_swave4 = df4["F_swave"]
F_dwave4 = df4["F_dwave"]
F_px4 = df4["F_px"]
F_py4 = df4["F_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.abs(F0), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps4, np.abs(F_px4), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps4, np.abs(F_py4), "--", linewidth=1, label=r"$p_y$-wave", color='red')

# plt.ylim(0,0.05)
# plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# print(converged2)

# %%
df5 = np.load('./data/SFP_U7.npz')
temps5 = df5["temps"]
converged5 = df5["converged"]
F05 = df5["F0"]
F_swave5 = df5["F_swave"]
F_dwave5 = df5["F_dwave"]
F_px5 = df5["F_px"]
F_py5 = df5["F_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.abs(F0), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps5, np.abs(F_px5), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps5, np.abs(F_py5), "--", linewidth=1, label=r"$p_y$-wave", color='red')

# plt.ylim(0,0.05)
# plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# print(converged2)

# %%
df3 = np.load('./data/SFP.npz')
temps3 = df3["temps"]
converged3 = df3["converged"]
F03 = df3["F0"]
F_swave3 = df3["F_swave"]
F_dwave3 = df3["F_dwave"]
F_px3 = df3["F_px"]
F_py3 = df3["F_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps3, np.abs(F0), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps3, np.abs(F_px3), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps3, np.abs(F_py3), "--", linewidth=1, label=r"$p_y$-wave", color='red')

plt.ylim(0,0.05)
plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.savefig("../../figures/SFP_U325.svg", bbox_inches="tight")
plt.show()
print(F0[0])
# Out:
# (0.21897990942057402-0.0010918314963580453j)

# %%
plt.figure(1)
plt.clf()

# plt.plot(temps, np.abs(F0), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps1, np.abs(F_px1), linewidth=1, label=r"U=3", color='black')
plt.plot(temps1, np.abs(F_py1), "--", linewidth=1, color='black')
plt.plot(temps3, np.abs(F_px3), linewidth=1, label=r"U=4", color='blue')
plt.plot(temps3, np.abs(F_py3), "--", linewidth=1, color='blue')
plt.plot(temps2, np.abs(F_px2), linewidth=1, label=r"U=5", color='red')
plt.plot(temps2, np.abs(F_py2), "--", linewidth=1, color='red')
plt.plot(temps2, np.abs(F_px4), linewidth=1, label=r"U=6", color='orange')
plt.plot(temps2, np.abs(F_py4), "--", linewidth=1, color='orange')
plt.plot(temps2, np.abs(F_px5), linewidth=1, label=r"U=7", color='green')
plt.plot(temps2, np.abs(F_py5), "--", linewidth=1, color='green')

# plt.ylim(0,0.05)
# plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
plt.figure(1)
plt.clf()

# plt.plot(temps, np.abs(F0), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps1, np.abs(F01), linewidth=1, label=r"U=3", color='black')
plt.plot(temps3, np.abs(F03), linewidth=1, label=r"U=4", color='blue')
plt.plot(temps2, np.abs(F02), linewidth=1, label=r"U=5", color='red')
plt.plot(temps2, np.abs(F04), linewidth=1, label=r"U=6", color='orange')
plt.plot(temps2, np.abs(F05), linewidth=1, label=r"U=7", color='green')

# plt.ylim(0,0.05)
# plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
V_arr = np.array([
    1,2,3,4,5,
    5.5,6,6.5,7,
    7.5,8,8.5,9,9.5
])

dwave_arr = np.array([
    0.07912, 0.12194, 0.143596, 0.156518, 0.16489,
    0.2, 0.225, 0.25, 0.275,
    0.3, 0.325, 0.35, 0.375, 0.4
]) * V_arr

temps = np.concatenate([
    np.arange(0.001, 0.009 + 1e-12, 0.001),
    np.arange(0.010, 0.080 + 1e-12, 0.01),
    np.arange(0.0805, 0.1100 + 1e-12, 0.0005),
    np.arange(0.115, 0.300 + 1e-12, 0.001),
])  # 263 temps total

temps_num = len(temps)
V_num = len(V_arr)

print(np.where(np.isclose(temps, 0.2)))
# Out:
# (array([162]),)

# %%
df = np.load('./data/DFP_hx_mult.npz')
temps_df = df["temps"].reshape(V_num, temps_num)
F0 = df["F0"].reshape(V_num, temps_num)
F_swave = df["F_swave"].reshape((V_num, temps_num))
F_dwave = df["F_dwave"].reshape((V_num, temps_num))
F_px = df["F_px"].reshape((V_num, temps_num))
F_py = df["F_py"].reshape((V_num, temps_num))
Fuu_px = df["Fuu_px"].reshape((V_num, temps_num))
Fuu_py = df["Fuu_py"].reshape((V_num, temps_num))
Fdd_px = df["Fdd_px"].reshape((V_num, temps_num))
Fdd_py = df["Fdd_py"].reshape((V_num, temps_num))

# %%
I = np.abs(Fuu_px - Fdd_px) / 2
threshold = 0.05 * I.max()

Tc_direct = []
dwave_valid = []

for i, dw in enumerate(dwave_arr):
    row = I[i, :]
    above = row >= threshold
    crossings = np.where(np.diff(above.astype(int)))[0]
    
    if len(crossings) > 0:
        Tc_direct.append(temps[crossings[0]])
        dwave_valid.append(dw)

Tc20 = np.array(Tc_direct)
dwave20 = np.array(dwave_valid)
Tc20 = Tc20


plt.plot(dwave20, Tc20)

# %%
U_arr = np.array([
    1,2,3,4,5,
    5.5,6,6.5,7,
    7.5,8,8.5,9,9.5
])

swave_arr = np.array([
    0.07912, 0.12194, 0.143596, 0.156518, 0.16489,
    0.2, 0.225, 0.25, 0.275,
    0.3, 0.325, 0.35, 0.375, 0.4
]) * U_arr

temps = np.concatenate([
    np.arange(0.001, 0.009 + 1e-12, 0.001),
    np.arange(0.010, 0.100 + 1e-12, 0.001),
    np.arange(0.1005, 0.1400 + 1e-12, 0.0005),
    np.arange(0.141, 0.200 + 1e-12, 0.001),
])  # 240 temps total

U_num = len(U_arr)
temps_num = len(temps)
df_s = np.load('./data/SFP_hx_mult.npz')
temps_df_s = df_s["temps"].reshape(U_num, temps_num)
F0_s = df_s["F0"].reshape(U_num, temps_num)
F_swave_s = df_s["F_swave"].reshape((U_num, temps_num))
F_dwave_s = df_s["F_dwave"].reshape((U_num, temps_num))
F_px_s = df_s["F_px"].reshape((U_num, temps_num))
F_py_s = df_s["F_py"].reshape((U_num, temps_num))
Fuu_px_s = df_s["Fuu_px"].reshape((U_num, temps_num))
Fuu_py_s = df_s["Fuu_py"].reshape((U_num, temps_num))
Fdd_px_s = df_s["Fdd_px"].reshape((U_num, temps_num))
Fdd_py_s = df_s["Fdd_py"].reshape((U_num, temps_num))

# %%
I = np.abs(Fuu_px_s - Fdd_px_s) / 2
threshold = 0.05 * I.max()

Tc_direct = []
dwave_valid = []

for i, dw in enumerate(dwave_arr):
    row = I[i, :]
    above = row >= threshold
    crossings = np.where(np.diff(above.astype(int)))[0]
    
    if len(crossings) > 0:
        Tc_direct.append(temps[crossings[0]])
        dwave_valid.append(dw)

Tc_s = np.array(Tc_direct)
swave = np.array(dwave_valid)
Tc_s = Tc_s
plt.plot(swave, Tc_s)

# %%
plt.figure()
plt.plot(dwave20, Tc20, label='d-wave')
plt.plot(swave, Tc_s, label='s-wave')
plt.xlabel("$\Delta$", fontsize=15)
plt.ylabel("$T_c$", fontsize=15)
plt.legend()
plt.show()
