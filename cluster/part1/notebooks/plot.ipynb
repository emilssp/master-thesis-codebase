# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df = np.load('../data/bulkD.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_px), "--", linewidth=1, label=r"$p_y$-wave", color='red')

# plt.ylim(0,0.05)
# plt.xlim(0,0.15)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df = np.load('../data/bulkP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.plot(np.arange(0.4,0.61,0.01), np.zeros(21), color='black')
plt.plot(np.arange(0.4,0.61,0.01), np.zeros(21),'--', color='red')

plt.ylim(0,0.05)
plt.xlim(0,0.15)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
print(temps[np.where(df["converged"]==False)])
# Out:
# [0.1085 0.1086 0.1087]

# %%
print(int(2.5))
# Out:
# 2

# %%
df = np.load('../data/NP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()

# plt.axvline(0.286, color='pink') #  Temperature
# plt.axhline(0.058, color='pink') #  Gap

plt.plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
print(temps[np.where(df["converged"]==False)])

print(F_px)
# Out:
# [0.1072 0.1073 0.1074]
# [ 3.68652354e-02+0.j  3.71689005e-02+0.j  3.75230483e-02+0.j
#   3.78949605e-02+0.j  3.82502263e-02+0.j  3.85202262e-02+0.j
#   3.86583842e-02+0.j  3.86375977e-02+0.j  3.84380728e-02+0.j
#   3.80419744e-02+0.j  3.74291270e-02+0.j  3.65760682e-02+0.j
#   3.54532805e-02+0.j  3.40220354e-02+0.j  3.22365232e-02+0.j
#   3.00025787e-02+0.j  2.72004234e-02+0.j  2.36028711e-02+0.j
#   1.87113884e-02+0.j  1.07960752e-02+0.j  5.04398464e-12+0.j
#   4.90730846e-12+0.j  4.78757119e-12+0.j  4.67445389e-12+0.j
#   4.55893505e-12+0.j  4.45286277e-12+0.j  4.34892073e-12+0.j
#   4.23996681e-12+0.j  4.16068750e-12+0.j  4.06434064e-12+0.j
#   3.96602875e-12+0.j  3.88138396e-12+0.j  3.80611840e-12+0.j
#   3.73559126e-12+0.j  3.66650823e-12+0.j  3.59486950e-12+0.j
#   3.51734928e-12+0.j  3.45171103e-12+0.j  3.39521944e-12+0.j
#   3.32410280e-12+0.j  3.25686068e-12+0.j  3.21181012e-12+0.j
#   3.14535066e-12+0.j  3.09675614e-12+0.j  3.04352663e-12+0.j
#   2.98379397e-12+0.j  2.93662052e-12+0.j  2.90038949e-12+0.j
#   2.83200397e-12+0.j  2.79255279e-12+0.j  2.75974227e-12+0.j
#   2.71150259e-12+0.j  2.66735797e-12+0.j  2.62626675e-12+0.j
#   2.58692300e-12+0.j  2.54842956e-12+0.j  2.50948994e-12+0.j
#   2.46927845e-12+0.j  2.42650670e-12+0.j  2.40122255e-12+0.j
#   2.35041283e-12+0.j  2.31482632e-12+0.j  2.29315490e-12+0.j
#   2.26296946e-12+0.j  2.22256248e-12+0.j  2.19065095e-12+0.j
#   2.16427365e-12+0.j  2.13934163e-12+0.j  2.11078989e-12+0.j
#   2.87790703e-13+0.j  3.81135438e-17+0.j  1.54730773e-17+0.j
#   1.27219868e-17+0.j  1.62792502e-17+0.j  1.19379306e-17+0.j
#   1.71454340e-18+0.j  3.92825686e-18+0.j  1.76885074e-17+0.j
#   1.17694267e-17+0.j -4.82788962e-18+0.j -4.00400990e-18+0.j
#   1.99282539e-15+0.j  2.07617745e-15+0.j  2.18793034e-15+0.j
#   2.29627347e-15+0.j  2.42501247e-15+0.j  2.55726231e-15+0.j
#   2.71366465e-15+0.j  2.88668903e-15+0.j  2.95991754e-15+0.j
#   3.15522632e-15+0.j  3.24807124e-15+0.j  3.49311881e-15+0.j
#   3.61480196e-15+0.j  3.75627057e-15+0.j  3.90266050e-15+0.j
#   1.81206084e-14+0.j  4.06395480e-14+0.j  6.60631982e-14+0.j
#   8.62817602e-14+0.j  1.05301976e-13+0.j  1.10717795e-13+0.j]

# %%
df = np.load('../data/SP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()
# plt.plot(temps, np.real(F0))
plt.plot(temps, np.abs(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.abs(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.05)
plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
print(temps[np.where(df["converged"]==False)])
# Out:
# []

# %%
df = np.load('../data/SFP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()
plt.title("SFP - opposite spin")
plt.plot(temps, -np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.05)
plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

print(temps[np.where(np.isclose(temps,0.2))])
print(F_px[np.where(np.isclose(temps,0.2))])
# Out:
# [0.2]
# [-0.00019536+0.j]

# %%
import numpy as np
import matplotlib.pyplot as plt

df1 = np.load('../data/bulkP.npz')
df2 = np.load('../data/NP.npz')
df3 = np.load('../data/SP.npz')
df4 = np.load('../data/SFP.npz')

fig, axs = plt.subplots(2, 2, figsize=(12, 8))

temps = df1["temps"]
F_px = df1["F_px"]
F_py = df1["F_py"]
axs[0, 0].plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
axs[0, 0].plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
axs[0, 0].plot(np.arange(0.4,0.61,0.01), np.zeros(21), color='black')
axs[0, 0].plot(np.arange(0.4,0.61,0.01), np.zeros(21),'--', color='red')
axs[0, 0].set_ylim(0, 0.05)
axs[0, 0].set_xlim(0, 0.2)
# axs[0, 0].legend(fontsize=20)
axs[0, 0].set_xticks([])
axs[0, 0].tick_params(labelsize=16)

temps = df2["temps"]
F_px = df2["F_px"]
F_py = df2["F_py"]
axs[0, 1].plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
axs[0, 1].plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
axs[0, 1].set_ylim(0, 0.05)
axs[0, 1].set_xlim(0, 0.2)
# axs[0, 1].legend(fontsize=20)
axs[0, 1].set_xticks([])
axs[0, 1].set_yticks([])
axs[0, 1].tick_params(labelsize=16)

temps = df3["temps"]
F_px = df3["F_px"]
F_py = df3["F_py"]
axs[1, 0].plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
axs[1, 0].plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
axs[1, 0].set_ylim(0, 0.05)
axs[1, 0].set_xlim(0, 0.2)
# axs[1, 0].legend(fontsize=20)
axs[1, 0].tick_params(labelsize=16)
axs[1, 0].set_xlabel(r"$T/t$", fontsize=24)


temps = df4["temps"]
F_px = df4["F_px"]
F_py = df4["F_py"]
axs[1, 1].plot(temps, -np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
axs[1, 1].plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
axs[1, 1].set_ylim(0, 0.05)
axs[1, 1].set_xlim(0, 0.2)
axs[1, 1].set_yticks([])
# axs[1, 1].legend(fontsize=20)
axs[1, 1].tick_params(labelsize=16)
axs[1, 1].set_xlabel(r"$T/t$", fontsize=24)
plt.tight_layout()

plt.savefig("../../figures/pwave_Tc.svg", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 df1 = np.load('../data/bulkP.npz')
#       5 df2 = np.load('../data/NP.npz')
#       6 df3 = np.load('../data/SP.npz')
#
# File d:\miniconda3\envs\master-venv\lib\site-packages\numpy\lib\_npyio_impl.py:451, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     449     own_fid = False
#     450 else:
# --> 451     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     452     own_fid = True
#     454 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/bulkP.npz'

# %%
df = np.load('../data/bulkTSC.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["Fuu_px"]
F_py = df["Fuu_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.plot(np.arange(0.4,0.61,0.01), np.zeros(21), color='black')
plt.plot(np.arange(0.4,0.61,0.01), np.zeros(21),'--', color='red')

# plt.ylim(0,0.25)
plt.xlim(0,0.15)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
print(temps[np.where(df["converged"]==False)])
# Out:
# []

# %%
df = np.load('../data/DP.npz')
temps = df["temps"]
# converged = df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.abs(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:Re(p_x)$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:Im(p_y)$-wave")
# plt.plot(temps, np.real(Fdd_px), linewidth=1, label=r"$dd:p_x$-wave")
# plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$dd:p_y$-wave")
plt.ylim(0,0.25)
plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
print(temps[np.where(df["converged"]==False)])
print(temps[0])
print(Fuu_px[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = np.load('../data/DP.npz')
#       2 temps = df["temps"]
#       3 # converged = df["converged"]
#
# File d:\miniconda3\envs\master-venv\lib\site-packages\numpy\lib\_npyio_impl.py:451, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     449     own_fid = False
#     450 else:
# --> 451     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     452     own_fid = True
#     454 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/DP.npz'

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/SFP_hx.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()
plt.title("SFP - same spin")
plt.plot(temps, np.real(Fuu_px-Fdd_px)/2, linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(Fuu_py+Fdd_py)/2, "--", linewidth=1, label=r"$p_y$-wave", color='red')
# plt.plot(temps, np.real(Fdd_px), linewidth=1, label=r"$p_x$-wave", color='black')
# plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.05)
plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
print(temps[np.where(df["converged"]==False)])
# Out:
# []

# %%
print(temps[np.where(np.isclose(temps,0.2))])
print(Fuu_px[np.where(np.isclose(temps,0.2))]*2)
# Out:
# [0.2]
# [0.00032017-1.97166539e-11j]

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/DFP_hx.npz')
temps = df["temps"]
converged=df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:abs(p_x)$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:abs(p_y)$-wave")
plt.plot(temps, np.abs(F_px), linewidth=1, label=r"$uu:abs(p_x)$-wave")

# plt.plot(temps, np.abs(Fdd_px), linewidth=1, label=r"$dd:p_x$-wave")
# plt.plot(temps, np.abs(Fdd_py), "--", linewidth=1, label=r"$dd:p_y$-wave")
# plt.ylim(0,None)
# plt.xlim(0.1,0.6)
plt.axvline(0.396)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 df = np.load('../data/DFP_hx.npz')
#       5 temps = df["temps"]
#       6 converged=df["converged"]
#
# File d:\miniconda3\envs\master-venv\lib\site-packages\numpy\lib\_npyio_impl.py:451, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     449     own_fid = False
#     450 else:
# --> 451     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     452     own_fid = True
#     454 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/DFP_hx.npz'

# %%
print(temps[np.where(converged==False)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(temps[np.where(converged==False)])
#
# NameError: name 'converged' is not defined
