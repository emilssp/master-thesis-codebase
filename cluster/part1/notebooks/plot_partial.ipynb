# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df = np.load('../data/SFP_partial.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()
plt.plot(temps, -np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.05)
plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

print(temps[np.where(np.isclose(temps,0.2))])
print(F_px[np.where(np.isclose(temps,0.2))])
# Out:
# [0.2]
# [-0.00026171+0.j]

# %%
df = np.load('../data/SFP_hx_partial.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]
plt.figure(1)
plt.clf()
plt.plot(temps, np.abs(Fuu_px-Fdd_px)/2, linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.abs(Fuu_py+Fdd_py)/2, "--", linewidth=1, label=r"$p_y$-wave", color='red')
# plt.plot(temps, np.real(Fdd_px), linewidth=1, label=r"$p_x$-wave", color='black')
# plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.05)
plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
print(temps[np.where(df["converged"]==False)])
# Out:
# []

# %%
df = np.load('../data/SFP_hy_partial.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]
plt.figure(1)
plt.clf()
plt.plot(temps, np.abs(Fuu_px+Fdd_px)/2, linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.abs(Fuu_py+Fdd_py)/2, "--", linewidth=1, label=r"$p_y$-wave", color='red')
# plt.plot(temps, np.real(Fdd_px), linewidth=1, label=r"$p_x$-wave", color='black')
# plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.05)
plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/DFP_hx_partial.npz')
temps = df["temps"]
converged=df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()
plt.title("DFP - hx")
plt.plot(temps, np.real(Fuu_px-Fdd_px)/2, linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(Fuu_py+Fdd_py)/2, "--", linewidth=1, label=r"$p_y$-wave", color='red')
# plt.plot(temps, np.real(Fdd_px), linewidth=1, label=r"$p_x$-wave", color='black')
# plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.05)
plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
print(temps[np.where(df["converged"]==False)])
# Out:
# []

# %%
print(temps[np.where(converged==False)])
# Out:
# []

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/DFP_hy_partial.npz')
temps = df["temps"]
converged=df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()
plt.title("DFP - hy")
plt.plot(temps, np.abs(Fuu_px+Fdd_px)/2, linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.abs(Fuu_py+Fdd_py)/2, "--", linewidth=1, label=r"$p_y$-wave", color='red')
# plt.plot(temps, np.real(Fdd_px), linewidth=1, label=r"$p_x$-wave", color='black')
# plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.05)
plt.xlim(0,0.2)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
print(temps[np.where(df["converged"]==False)])
# Out:
# []

# %%
temps = np.concatenate([
    np.arange(0.001, 0.009 + 1e-12, 0.001),
    np.arange(0.010, 0.080 + 1e-12, 0.01),
    np.arange(0.0805, 0.1100 + 1e-12, 0.0005),
    np.arange(0.115, 0.300 + 1e-12, 0.001),
])  # 203 temps total

print(len(temps))
# Out:
# 263
