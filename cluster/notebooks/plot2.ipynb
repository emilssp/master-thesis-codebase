# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df = np.load('../data/bulkTSC.npz')
temps = df["temps"]
converged = df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:Re(p_x)$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:Im(p_y)$-wave")
# plt.plot(temps, np.real(Fdd_px), linewidth=1, label=r"$dd:p_x$-wave")
# plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$dd:p_y$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df = np.load('../data/DP.npz')
temps = df["temps"]
# converged = df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_px), linewidth=1, label=r"$px$-wave")
plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:Re(p_x)$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:Im(p_y)$-wave")
# plt.plot(temps, np.real(Fdd_px), linewidth=1, label=r"$dd:p_x$-wave")
# plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$dd:p_y$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df = np.load('../data/SFP_hx.npz')
temps = df["temps"]
# converged = df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

plt.figure(1)
plt.clf()
plt.plot(temps, np.real(Fuu_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(Fuu_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.plot(temps, np.real(F_px), linewidth=1, label=r"dd:$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"dd:$p_y$-wave", color='red')
plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
print(converged)
# Out:
# [False False False False False False False False False False False False
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True False False False False False False
#  False False False False False  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]

# %%
df = np.load('../data/DFP_hx_Bfield.npz')
temps = df["temps"]
# converged = df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

plt.figure(1)
plt.clf()
plt.plot(temps, np.real(Fuu_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, -np.imag(Fuu_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
# plt.plot(temps, np.real(F_px), linewidth=1, label=r"dd:$p_x$-wave", color='black')
# plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"dd:$p_y$-wave", color='red')
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
print(converged)
# Out:
# [False False False False False False False False False False False False
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True False False False False False False
#  False False False False False  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]

# %%
df = np.load('../data/SFP_hx2.npz')
temps = df["temps"]
# converged = df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

plt.figure(1)
plt.clf()
plt.plot(temps, np.real(Fuu_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(Fuu_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.25)
plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
