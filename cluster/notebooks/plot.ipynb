# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df = np.load('../data/bulkP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.plot(np.arange(0.4,0.61,0.01), np.zeros(21), color='black')
plt.plot(np.arange(0.4,0.61,0.01), np.zeros(21),'--', color='red')

plt.ylim(0,0.25)
plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df = np.load('../data/bulkS.npz')
temps = df["temps"]
F0 = df["F0"]

plt.figure(1)
plt.clf()
plt.plot(temps, np.real(F0), linewidth=1, label=r"$s$-wave")
# plt.axvline(temps[np.real(F0)<1e-6][0])
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
# print(temps[np.real(F0)<1e-6][0])

# %%
df = np.load('../data/bulkD.npz')
temps = df["temps"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]

plt.figure(1)
plt.clf()
plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
# plt.plot(temps, np.abs(F_px), linewidth=1, label=r"abs($px$)")

plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
from turtle import color


df = np.load('../data/NP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()

# plt.axvline(0.286, color='pink') #  Temperature
# plt.axhline(0.058, color='pink') #  Gap

plt.plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.25)
plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
import numpy as np

temps = np.concatenate([
    np.array([0.001]),  # add a very low temp for testing
    np.arange(0.01, 0.20 + 1e-12, 0.01),
    np.arange(0.21, 0.60 + 1e-12, 0.002),
])  # 217 temps total

print(len(temps))
# Out:
# 217

# %%
df = np.load('../data/SP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()
# plt.plot(temps, np.real(F0))
plt.plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.25)
plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
from calendar import c


df = np.load('../data/SFP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()
plt.plot(temps, -np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
plt.ylim(0,0.25)
plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df1 = np.load('../data/bulkP.npz')
df2 = np.load('../data/NP.npz')
df3 = np.load('../data/SP.npz')
df4 = np.load('../data/SFP.npz')

fig, axs = plt.subplots(2, 2, figsize=(12, 8))

temps = df1["temps"]
F_px = df1["F_px"]
F_py = df1["F_py"]
axs[0, 0].plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
axs[0, 0].plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
axs[0, 0].plot(np.arange(0.4,0.61,0.01), np.zeros(21), color='black')
axs[0, 0].plot(np.arange(0.4,0.61,0.01), np.zeros(21),'--', color='red')
axs[0, 0].set_ylim(0, 0.25)
axs[0, 0].set_xlim(0, 0.6)
axs[0, 0].legend(fontsize=20)
axs[0, 0].set_xticks([])
axs[0, 0].tick_params(labelsize=16)

temps = df2["temps"]
F_px = df2["F_px"]
F_py = df2["F_py"]
axs[0, 1].plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
axs[0, 1].plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
axs[0, 1].set_ylim(0, 0.25)
axs[0, 1].set_xlim(0, 0.6)
axs[0, 1].legend(fontsize=20)
axs[0, 1].set_xticks([])
axs[0, 1].set_yticks([])
axs[0, 1].tick_params(labelsize=16)

temps = df3["temps"]
F_px = df3["F_px"]
F_py = df3["F_py"]
axs[1, 0].plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
axs[1, 0].plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
axs[1, 0].set_ylim(0, 0.25)
axs[1, 0].set_xlim(0, 0.6)
axs[1, 0].legend(fontsize=20)
axs[1, 0].tick_params(labelsize=16)
axs[1, 0].set_xlabel(r"$T/t$", fontsize=24)


temps = df4["temps"]
F_px = df4["F_px"]
F_py = df4["F_py"]
axs[1, 1].plot(temps, -np.real(F_px), linewidth=1, label=r"$p_x$-wave", color='black')
axs[1, 1].plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave", color='red')
axs[1, 1].set_ylim(0, 0.25)
axs[1, 1].set_xlim(0, 0.6)
axs[1, 1].set_yticks([])
axs[1, 1].legend(fontsize=20)
axs[1, 1].tick_params(labelsize=16)
axs[1, 1].set_xlabel(r"$T/t$", fontsize=24)
plt.tight_layout()
plt.savefig("../../../affinity/pwaveTc.svg")

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/bulkTSC.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.real(Fuu_px), linewidth=1, label=r"$uu:p_x$-wave", color='b')
plt.plot(temps, np.imag(Fuu_py), linewidth=1, label=r"$uu:p_y$-wave", color='g')
plt.plot(temps, np.real(Fdd_px), "--", linewidth=1, label=r"$dd:p_x$-wave", color='r')
plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$dd:p_y$-wave", color='k')
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.title("Bulk TSC", fontsize=15)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df = np.load('../data/DP.npz')
temps = df["temps"]
# converged = df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:Re(p_x)$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:Im(p_y)$-wave")
# plt.plot(temps, np.real(Fdd_px), linewidth=1, label=r"$dd:p_x$-wave")
# plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$dd:p_y$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/SFP_hx.npz')
temps = df["temps"]
F0 = df["F0"]
converged = df["converged"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.abs(F0), linewidth=1, label=r"F0")
# plt.plot(temps, np.abs(F_dwave), linewidth=1, label=r"$d$-wave")
# plt.plot(temps, np.abs(F_swave), linewidth=1, label=r"$s$-wave")
# # plt.plot(temps, np.imag(Fuu_py), "--", linewidth=1, label=r"$uu:p_y$-wave")
plt.plot(temps, np.abs(F_px), linewidth=1, label=r"$p_x$-wave")
plt.plot(temps, np.abs(F_py), "--", linewidth=1, label=r"$p_y$-wave")
plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:abs(p_x)$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:abs(p_y)$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.axvline(0.345)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

print(converged)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/SFP_hy.npz')
temps = df["temps"]
converged = df["converged"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.abs(F0), linewidth=1, label=r"F0")
# plt.plot(temps, np.abs(F_dwave), linewidth=1, label=r"$d$-wave")
# plt.plot(temps, np.abs(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.imag(Fuu_py), "--", linewidth=1, label=r"$uu:p_y$-wave")
# plt.plot(temps, np.abs(F_px), linewidth=1, label=r"$p_x$-wave")
# plt.plot(temps, np.abs(F_py), "--", linewidth=1, label=r"$p_y$-wave")
plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:abs(p_x)$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:abs(p_y)$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.axvline(0.345)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
print(converged)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/DFP_hx.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.abs(F_dwave), linewidth=1, label=r"$d$-wave")
# plt.plot(temps, np.real(Fuu_px), linewidth=1, label=r"$uu:p_x$-wave")
# plt.plot(temps, np.imag(Fuu_py), "--", linewidth=1, label=r"$uu:p_y$-wave")
# plt.plot(temps, np.imag(Fuu_px), linewidth=1, label=r"$dd:p_x$-wave")
# plt.plot(temps, np.real(Fuu_py), "--", linewidth=1, label=r"$dd:p_y$-wave")
plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:abs(p_x)$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:abs(p_y)$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.axvline(0.345)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
temps = np.concatenate([
    np.arange(0.001, 0.020 + 1e-12, 0.001),
    np.arange(0.021, 0.040 + 1e-12, 0.0002),
    np.arange(0.041, 0.061 + 1e-12, 0.0002),
])

print(len(temps))
# Out:
# 217

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/DFP_hy.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

plt.plot(temps, np.abs(F_dwave), linewidth=1, label=r"$Re(d)$-wave")
# plt.plot(temps, np.imag(F_dwave), linewidth=1, label=r"$Re(d)$-wave")
plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:abs(p_x)$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:abs(p_y)$-wave")
plt.plot(temps, np.abs(F_px), linewidth=1, label=r"$uu:abs(p_x)$-wave")

# plt.plot(temps, np.abs(Fdd_px), linewidth=1, label=r"$dd:p_x$-wave")
# plt.plot(temps, np.abs(Fdd_py), "--", linewidth=1, label=r"$dd:p_y$-wave")
# plt.ylim(0,None)
# plt.xlim(0.1,0.6)
plt.axvline(0.396)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
print(F_dwave)
# Out:
# [0.18502281+0.21986451j 0.1850178 +0.21986866j 0.1850179 +0.21986847j
#  0.18502404+0.21986321j 0.18503115+0.21985713j 0.18503629+0.21985273j
#  0.18503792+0.21985129j 0.18503509+0.2198536j  0.18502721+0.21986016j
#  0.185014  +0.21987123j 0.18465082+0.22017596j 0.18420025+0.2205538j
#  0.18393858+0.22077596j 0.18381555+0.22088794j 0.18478939+0.2200917j
#  0.18529395+0.21969582j 0.18587257+0.21924885j 0.186544  +0.21873635j
#  0.1873033 +0.2181632j  0.18814284+0.21753578j 0.18905502+0.21685948j
#  0.19003283+0.21613799j 0.19107   +0.21537309j 0.19216092+0.21456459j
#  0.19330072+0.2137104j  0.19448524+0.21280666j 0.19571112+0.21184782j
#  0.19697589+0.2108268j  0.19827813+0.20973495j 0.19961762+0.2085621j
#  0.20099551+0.20729644j 0.20241458+0.20592426j 0.20387945+0.20442967j
#  0.20539695+0.20279404j 0.20697651+0.20099528j 0.20863074+0.19900684j
#  0.21037615+0.19679617j 0.21223428+0.1943226j  0.21423326+0.19153405j
# ...
