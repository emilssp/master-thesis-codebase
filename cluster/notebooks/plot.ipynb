# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df = np.load('../data/bulkP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave")
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df = np.load('../data/bulkS.npz')
temps = df["temps"]
F0 = df["F0"]

plt.figure(1)
plt.clf()
plt.plot(temps, np.real(F0), linewidth=1, label=r"$s$-wave")
# plt.axvline(temps[np.real(F0)<1e-6][0])
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
# print(temps[np.real(F0)<1e-6][0])

# %%
df = np.load('../data/bulkD.npz')
temps = df["temps"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]

plt.figure(1)
plt.clf()
plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.abs(F_px), linewidth=1, label=r"abs($px$)")

plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df = np.load('../data/NP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()

# plt.axvline(0.286, color='pink') #  Temperature
# plt.axhline(0.058, color='pink') #  Gap

plt.plot(temps, np.imag(F_px), linewidth=1, label=r"$p_x$-wave")
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave")
# plt.ylim(0,0.25)

# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
import numpy as np

temps = np.concatenate([
    np.array([0.001]),  # add a very low temp for testing
    np.arange(0.01, 0.20 + 1e-12, 0.01),
    np.arange(0.21, 0.60 + 1e-12, 0.002),
])  # 217 temps total

print(len(temps))
# Out:
# 217

# %%
df = np.load('../data/SP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()
# plt.plot(temps, np.real(F0))
plt.plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave")
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df = np.load('../data/SFP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]

plt.figure(1)
plt.clf()
plt.plot(temps, np.real(F_px), linewidth=1, label=r"$p_x$-wave")
plt.plot(temps, np.imag(F_py), "--", linewidth=1, label=r"$p_y$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/bulkTSC.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
plt.plot(temps, np.real(Fuu_px), linewidth=1, label=r"$uu:p_x$-wave", color='b')
plt.plot(temps, np.imag(Fuu_py), linewidth=1, label=r"$uu:p_y$-wave", color='g')
plt.plot(temps, np.real(Fdd_px), "--", linewidth=1, label=r"$dd:p_x$-wave", color='r')
plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$dd:p_y$-wave", color='k')
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
df = np.load('../data/DP.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
# plt.plot(temps, np.real(F_px), linewidth=1, label=r"$uu:p_x$-wave")
# plt.plot(temps, np.imag(Fuu_py), "--", linewidth=1, label=r"$uu:p_y$-wave")
plt.plot(temps, np.real(Fdd_px), linewidth=1, label=r"$dd:p_x$-wave")
plt.plot(temps, np.imag(Fdd_py), "--", linewidth=1, label=r"$dd:p_y$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/DFP_hx.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
plt.plot(temps, np.abs(F_dwave), linewidth=1, label=r"$d$-wave")
# plt.plot(temps, np.real(Fuu_px), linewidth=1, label=r"$uu:p_x$-wave")
# plt.plot(temps, np.imag(Fuu_py), "--", linewidth=1, label=r"$uu:p_y$-wave")
# plt.plot(temps, np.imag(Fuu_px), linewidth=1, label=r"$dd:p_x$-wave")
# plt.plot(temps, np.real(Fuu_py), "--", linewidth=1, label=r"$dd:p_y$-wave")
plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:p_x$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:p_y$-wave")
# plt.ylim(0,0.25)
# plt.xlim(0,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()

# %%
temps = np.concatenate([
    np.arange(0.001, 0.020 + 1e-12, 0.001),
    np.arange(0.021, 0.040 + 1e-12, 0.0002),
    np.arange(0.041, 0.061 + 1e-12, 0.0002),
])

print(len(temps))
# Out:
# 217

# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load('../data/DFP_hy.npz')
temps = df["temps"]
F0 = df["F0"]
F_swave = df["F_swave"]
F_dwave = df["F_dwave"]
F_px = df["F_px"]
F_py = df["F_py"]
Fuu_px = df["Fuu_px"]
Fuu_py = df["Fuu_py"]
Fdd_px = df["Fdd_px"]
Fdd_py = df["Fdd_py"]

plt.figure(1)
plt.clf()

# plt.plot(temps, np.real(F_swave), linewidth=1, label=r"$s$-wave")
# plt.plot(temps, np.real(F_dwave), linewidth=1, label=r"$d$-wave")
# plt.plot(temps, np.real(Fuu_px), linewidth=1, label=r"$uu:p_x$-wave")
# plt.plot(temps, np.imag(Fuu_py), "--", linewidth=1, label=r"$uu:p_y$-wave")
# plt.plot(temps, np.imag(Fuu_px), linewidth=1, label=r"$uu:p_x$-wave")
# plt.plot(temps, np.real(Fuu_py), "--", linewidth=1, label=r"$uu:p_y$-wave")
plt.plot(temps, np.abs(Fuu_px), linewidth=1, label=r"$uu:p_x$-wave")
plt.plot(temps, np.abs(Fuu_py), "--", linewidth=1, label=r"$uu:p_y$-wave")

# plt.plot(temps, np.abs(Fdd_px), linewidth=1, label=r"$dd:p_x$-wave")
# plt.plot(temps, np.abs(Fdd_py), "--", linewidth=1, label=r"$dd:p_y$-wave")
# plt.ylim(0,0.25)
plt.xlim(0.1,0.6)
plt.xlabel("T", fontsize=15)
plt.legend(loc="best", fontsize=12)
plt.tight_layout()
plt.show()
