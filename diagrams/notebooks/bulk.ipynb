# %%
import sys
from pathlib import Path
sys.path[:0] = [str(Path.cwd().parent)]

import numpy as np
import matplotlib.pyplot as plt
from self_consistency_k import bdg_sc_full_k

# %%
t=1
mu=1.8
T = 0.01

U=0
V_prime=0
V=1.5

Nx, Ny = 60, 60

out = bdg_sc_full_k(
    t, mu, Nx, Ny, 
    U=U, V=V, V_prime=V_prime,
    temperature=T, maxiter=5000,
    verbose=False, atol=1e-6,rtol=1e-3,
    F_init=np.array([0.1, -0.1, 0.1j, -0.1j], dtype=np.complex128),
)

# %%
print(f"F_swave: {out.F_swave}, F_dwave: {out.F_dwave}")
print(f"F_px: {out.F_px*2}, F_py: {out.F_py}")
print(f"Free_energy = {out.free_energy}")
# Out:
# F_swave: (6.7543863051936e-18-2.6020852139652106e-18j), F_dwave: (3.653954550667242e-18+8.673617379884035e-19j)
# F_px: (0.03810360148162391+1.9062052961484402e-17j), F_py: (-5.2632774457810104e-18+0.019051800740811958j)
# Free_energy = -8031.155183232229
