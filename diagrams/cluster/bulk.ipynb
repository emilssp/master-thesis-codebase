# %%
import sys
from pathlib import Path
sys.path[:0] = [str(Path.cwd().parent)]

import numpy as np
import matplotlib.pyplot as plt

from scripts.self_consistency_k import bdg_sc_full_k

# %%
# Set up Hamiltonian parameters

t = 1.0
mu = 1.2 * t
T = 0.001 * t

U = 0.0
V_prime = 0.0
V = 0.5 * t

# Lattice parameters
Nx, Ny = 100, 100

# Tolerances and maximum iterations for self-consistency
atol = 1e-6
rtol = 1e-3
maxiter = 5000


out = bdg_sc_full_k(
    t, mu, temperature=T,
    V=V, Nx=Nx, Ny=Ny,
    atol=atol, rtol=rtol,
    maxiter=maxiter,
    F_init=[0.01, -0.01, 0.01j, -0.01j]
)

# %%
print(f"F_onsite: {out.F_onsite}")
print(f"F_swave: {out.F_swave}, F_dwave: {out.F_dwave}")
print(f"F_px: {out.F_px}, F_py: {out.F_py}")
print(f"Free_energy = {out.free_energy}")
# Out:
# F_onsite: (7.374011029532072e-20+9.107489751754148e-20j)
# F_swave: (-3.771297474038904e-20-5.565190456220634e-20j), F_dwave: (2.5557994999736625e-20+4.83936814254694e-21j)
# F_px: (2.5189177432557125e-15-6.02523253653725e-20j), F_py: (-6.56350098147682e-20+2.518973240087926e-15j)
# Free_energy = -19201.343075709126
