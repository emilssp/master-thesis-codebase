# %%
import numpy as np
import pandas as pd

from constants import *
from self_consistency_k import bdg_sc_full_k

# %%
t=1
V_prime= 1.5

h = np.array([0, 0, 0])
Nx, Ny = 75, 75

atol = 1e-5
rtol = 1e-3
maxiter=200
mu = -2

temps = np.linspace(0.0001, 0.1, 1)

rows = []

for idx, temp in enumerate(temps):
    print(f"Running job {idx+1} out of {len(temps)}")

    V_prime = 1.5 * t 

    out = bdg_sc_full_k(
        t, mu, Nx, Ny, temp, 
        V_prime=V_prime, h=[0,0,1],
        atol=atol, rtol=rtol, maxiter=maxiter,
        Fuu_init=np.array([0.1, -0.1, 0.1j, -0.1j]),
        Fdd_init=np.array([0.1, -0.1, 0.1j, -0.1j])
    )

    rows.append({
        "idx": idx,
        "temp": temp,
        "Fuu_px": out.Fuu_px,
        "Fuu_py": out.Fuu_py,
        "Fdd_px": out.Fdd_px,
        "Fdd_py": out.Fdd_py,
    })

df = pd.DataFrame(rows)
# Out:
# Running job 1 out of 1

# %%
t=1
V_prime= 1.5

h = np.array([0, 0, 0])
Nx, Ny = 75, 75

atol = 1e-5
rtol = 1e-3
maxiter=200
mu = +2

temps = np.linspace(0.0001, 0.1, 1)

for idx, temp in enumerate(temps):
    print(f"Running job {idx+1} out of {len(temps)}")

    V_prime = 1.5 * t 

    out = bdg_sc_full_k(
        t, mu, Nx, Ny, temp, 
        V_prime=V_prime, h=[0,0,1],
        atol=atol, rtol=rtol, maxiter=maxiter,
        Fuu_init=np.array([0.1, -0.1, 0.1j, -0.1j]),
        Fdd_init=np.array([0.1, -0.1, 0.1j, -0.1j])
    )

    rows.append({
        "idx": idx,
        "temp": temp,
        "Fuu_px": out.Fuu_px,
        "Fuu_py": out.Fuu_py,
        "Fdd_px": out.Fdd_px,
        "Fdd_py": out.Fdd_py,
    })

df = pd.DataFrame(rows)
# Out:
# Running job 1 out of 1
# ==================================================
# WARNING: Failed to converge after 200 iterations
# ==================================================

# %%
df.iloc[:]
# Out:
#    idx    temp              Fuu_px              Fuu_py              Fdd_px  \
# 0    0  0.0001  0.002403+0.000000j -0.000000+0.002403j  0.035728+0.000000j
# 1    0  0.0001  0.035789-0.000000j  0.000000+0.035789j  0.000039+0.000000j
#
#                Fdd_py
# 0 -0.000000+0.035728j
# 1 -0.000000+0.000039j
