# %%
import sys
from pathlib import Path
sys.path[:0] = [str(Path.cwd().parent)]

import numpy as np
import matplotlib.pyplot as plt

from scripts.Hamiltonian import Hamiltonian
from scripts.Lattice import Lattice
from scripts.self_consistency import bdg_sc

# %%
widthD = 10
widthP = 15

X, Y = widthD+widthP, 200
lattice = Lattice(X, Y)

t = 1
T = 0.1

muD = 0.1 * t
muP = 0.1 * t
muF = 1.4 * t
mu = np.zeros(lattice.X)
mu[:widthD] = muD
mu[widthD:] = muP

V_prime0 = 1.5 * t
V_prime = V_prime0 * np.ones(lattice.X)
V_prime[:widthD] = 0 

V0 = 1.5 * t
V = V0 * np.ones(lattice.X)
V[widthD:] = 0 

plt.figure(figsize=(6,2))
if V is not None:
    plt.plot(V, '-o', label="V")
if V_prime is not None:
    plt.plot(V_prime, '-o', label="V'",)
plt.plot(mu, '-o', label='mu')
# plt.plot(hz, '-o', label='hz') 
plt.legend()

# %%
H = Hamiltonian(t, mu, lattice, U=None, V_prime=V_prime, V=V,
                F_init=[0.1, 0.1, -0.1, -0.1],
                Fuu_init=[0.1, -0.1, 0.1j, -0.1j],
                Fdd_init=[0.1, -0.1, 0.1j, -0.1j],
                F0_init=0.1)

# %%
plt.figure(figsize=(6,2))
if V is not None:
    plt.plot(np.real(H.F_xplus), label="x+", linestyle='--', lw=2)
    plt.plot(np.real(H.F_xmin), label="x-", linestyle='-.', lw=2)
if V_prime is not None:
    plt.plot(np.real(H.Fuu_xplus), label="uu:x+", linestyle='--', lw=2)
    plt.plot(np.real(H.Fuu_xmin), label="uu:x-", linestyle='-.', lw=2)
plt.legend()
plt.axvline(widthD)

# %%
F_swave, F_dwave, F_px, F_py = bdg_sc(H, atol=1e-4, rtol=0.01, maxiter=200, verbose=False, temperature=T)
# Out:
# ==================================================
# Converged after 84 iterations
# ==================================================

# %%
F, Fuu, Fdd = H.get_correlations()

# %%
x = np.arange(1, widthD + widthP + 1)

fig, axs = plt.subplots(1, 1, figsize=(8, 6))
axs.set_title(f"T/t={T}, hz/t={0}")

axs.axvline(widthD, color='black', linestyle='--')
axs.axvline(widthD, color='black', linestyle='--')
axs.plot(x, np.real(F_dwave), label="d-wave")
axs.plot(x, np.real(F_px), label="px")
axs.plot(x, np.real(F_py), label="py")
axs.plot(x, np.real(Fuu.px), label="uu: Re(p_x-wave)")
axs.plot(x, np.imag(Fuu.py), "--", label="uu: Im(p_y-wave)")
axs.plot(x, np.real(Fdd.px), label="dd: Re(p_x-wave)")
axs.plot(x, np.imag(Fdd.py), "--", label="dd: Im(p_y-wave)")

# axs.set_ylim(None, 0.4)
# axs.set_xlim(20, 45)
axs.set_xlabel("x", fontsize=15)
axs.legend(fontsize=12, loc="best")
plt.savefig('../figures/DP.pdf')
plt.show()

# %%
x = np.arange(1, widthD + widthP + 1)

fig, axs = plt.subplots(1, 1, figsize=(8, 6))
axs.set_title(f"T/t={T}")

axs.axvline(widthD, color='black', linestyle='--')
axs.axvline(widthD, color='black', linestyle='--')
axs.plot(x, np.abs(F_dwave), label="d-wave")
axs.plot(x, np.sqrt(np.real(Fuu.px)**2 + np.imag(Fuu.px)**2), label="abs(p_x-wave)")
axs.plot(x, np.sqrt(np.real(Fuu.py)**2 + np.imag(Fuu.py)**2), label="abs(p_y-wave)")

axs.set_ylim(None, 0.4)
axs.set_xlim(20, 45)
axs.set_xlabel("x", fontsize=15)
axs.legend(fontsize=12, loc="best")
plt.savefig('../figures/DFP.pdf')
plt.show()
